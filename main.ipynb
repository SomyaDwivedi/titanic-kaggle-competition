# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.preprocessing import StandardScaler

# Load CSV files
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")

# Encode categorical variable 'Sex'
train_data.replace({'male': 0, 'female': 1}, inplace=True)
test_data.replace({'male': 0, 'female': 1}, inplace=True)

# Fill missing values
train_data["Age"].fillna(train_data["Age"].mean(), inplace=True)
train_data["Fare"].fillna(train_data["Fare"].mean(), inplace=True)
train_data["Embarked"].fillna(train_data["Embarked"].mode()[0], inplace=True)

test_data["Age"].fillna(test_data["Age"].mean(), inplace=True)
test_data["Fare"].fillna(test_data["Fare"].mean(), inplace=True)
test_data["Embarked"].fillna(test_data["Embarked"].mode()[0], inplace=True)

# Drop PassengerId and Name (not useful for prediction)
train_data.drop(columns=["PassengerId", "Name", "Ticket", "Cabin"], inplace=True)
test_data.drop(columns=["PassengerId", "Name", "Ticket", "Cabin"], inplace=True)

# Convert categorical 'Embarked' to numerical
train_data = pd.get_dummies(train_data, columns=["Embarked"], drop_first=True)
test_data = pd.get_dummies(test_data, columns=["Embarked"], drop_first=True)

# Define features and target
X_train = train_data.drop(columns=["Survived"]).values
y_train = train_data["Survived"].values

X_test = test_data.values  # No Survived column in test data

# Standardize features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Build a deeper model
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.2),  # Helps prevent overfitting
    Dense(16, activation='relu'),
    Dropout(0.2),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Train model
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)

# Predict on test set
predictions = (model.predict(X_test) > 0.5).astype(int)

# Save predictions
output = pd.DataFrame({"Prediction": predictions.flatten()})
output.to_csv("predictions.csv", index=False)
print("Predictions saved to predictions.csv")
# Out:
# Epoch 1/100
# /tmp/ipykernel_1381/3828029951.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train_data.replace({'male': 0, 'female': 1}, inplace=True)
# /tmp/ipykernel_1381/3828029951.py:14: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_data.replace({'male': 0, 'female': 1}, inplace=True)
# /tmp/ipykernel_1381/3828029951.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_data["Age"].fillna(train_data["Age"].mean(), inplace=True)
# /tmp/ipykernel_1381/3828029951.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_data["Fare"].fillna(train_data["Fare"].mean(), inplace=True)
# /tmp/ipykernel_1381/3828029951.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_data["Embarked"].fillna(train_data["Embarked"].mode()[0], inplace=True)
# /tmp/ipykernel_1381/3828029951.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_data["Age"].fillna(test_data["Age"].mean(), inplace=True)
# /tmp/ipykernel_1381/3828029951.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_data["Fare"].fillna(test_data["Fare"].mean(), inplace=True)
# /tmp/ipykernel_1381/3828029951.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_data["Embarked"].fillna(test_data["Embarked"].mode()[0], inplace=True)
# /home/somya/tensorflow_env/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.5992 - loss: 0.6689 - val_accuracy: 0.6760 - val_loss: 0.5976
# Epoch 2/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6878 - loss: 0.5953 - val_accuracy: 0.7318 - val_loss: 0.5419
# Epoch 3/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6470 - loss: 0.5952 - val_accuracy: 0.7765 - val_loss: 0.5143
# Epoch 4/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7235 - loss: 0.5522 - val_accuracy: 0.8156 - val_loss: 0.4928
# Epoch 5/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7298 - loss: 0.5576 - val_accuracy: 0.8324 - val_loss: 0.4789
# Epoch 6/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7210 - loss: 0.5616 - val_accuracy: 0.8324 - val_loss: 0.4711
# Epoch 7/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7587 - loss: 0.5288 - val_accuracy: 0.8380 - val_loss: 0.4510
# Epoch 8/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7687 - loss: 0.5156 - val_accuracy: 0.8380 - val_loss: 0.4386
# Epoch 9/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7553 - loss: 0.5135 - val_accuracy: 0.8380 - val_loss: 0.4291
# Epoch 10/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7493 - loss: 0.5035 - val_accuracy: 0.8380 - val_loss: 0.4245
# Epoch 11/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7691 - loss: 0.5209 - val_accuracy: 0.8436 - val_loss: 0.4209
# Epoch 12/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7934 - loss: 0.4900 - val_accuracy: 0.8380 - val_loss: 0.4089
# Epoch 13/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7626 - loss: 0.4979 - val_accuracy: 0.8492 - val_loss: 0.4048
# Epoch 14/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7662 - loss: 0.4854 - val_accuracy: 0.8603 - val_loss: 0.3982
# Epoch 15/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7671 - loss: 0.4921 - val_accuracy: 0.8659 - val_loss: 0.3967
# Epoch 16/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7909 - loss: 0.4734 - val_accuracy: 0.8603 - val_loss: 0.3906
# Epoch 17/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7733 - loss: 0.4869 - val_accuracy: 0.8547 - val_loss: 0.3867
# Epoch 18/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7877 - loss: 0.4647 - val_accuracy: 0.8547 - val_loss: 0.3824
# Epoch 19/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7874 - loss: 0.4679 - val_accuracy: 0.8547 - val_loss: 0.3803
# Epoch 20/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7695 - loss: 0.4718 - val_accuracy: 0.8603 - val_loss: 0.3756
# Epoch 21/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7900 - loss: 0.4719 - val_accuracy: 0.8603 - val_loss: 0.3753
# Epoch 22/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7814 - loss: 0.4753 - val_accuracy: 0.8659 - val_loss: 0.3731
# Epoch 23/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7956 - loss: 0.4582 - val_accuracy: 0.8659 - val_loss: 0.3674
# Epoch 24/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7944 - loss: 0.4797 - val_accuracy: 0.8603 - val_loss: 0.3680
# Epoch 25/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7866 - loss: 0.4621 - val_accuracy: 0.8603 - val_loss: 0.3592
# Epoch 26/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7900 - loss: 0.4909 - val_accuracy: 0.8603 - val_loss: 0.3592
# Epoch 27/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7882 - loss: 0.4875 - val_accuracy: 0.8603 - val_loss: 0.3586
# Epoch 28/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7922 - loss: 0.4636 - val_accuracy: 0.8603 - val_loss: 0.3603
# Epoch 29/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7774 - loss: 0.4868 - val_accuracy: 0.8603 - val_loss: 0.3605
# Epoch 30/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8010 - loss: 0.4537 - val_accuracy: 0.8603 - val_loss: 0.3570
# Epoch 31/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7850 - loss: 0.4934 - val_accuracy: 0.8603 - val_loss: 0.3598
# Epoch 32/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8305 - loss: 0.4160 - val_accuracy: 0.8547 - val_loss: 0.3577
# Epoch 33/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8095 - loss: 0.4545 - val_accuracy: 0.8603 - val_loss: 0.3576
# Epoch 34/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8013 - loss: 0.4904 - val_accuracy: 0.8603 - val_loss: 0.3567
# Epoch 35/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8042 - loss: 0.4744 - val_accuracy: 0.8547 - val_loss: 0.3553
# Epoch 36/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8065 - loss: 0.4388 - val_accuracy: 0.8659 - val_loss: 0.3541
# Epoch 37/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8039 - loss: 0.4566 - val_accuracy: 0.8547 - val_loss: 0.3563
# Epoch 38/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8042 - loss: 0.4498 - val_accuracy: 0.8603 - val_loss: 0.3553
# Epoch 39/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8120 - loss: 0.4214 - val_accuracy: 0.8547 - val_loss: 0.3520
# Epoch 40/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8335 - loss: 0.4037 - val_accuracy: 0.8492 - val_loss: 0.3491
# Epoch 41/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8248 - loss: 0.4172 - val_accuracy: 0.8547 - val_loss: 0.3480
# Epoch 42/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8288 - loss: 0.4047 - val_accuracy: 0.8547 - val_loss: 0.3480
# Epoch 43/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8327 - loss: 0.4046 - val_accuracy: 0.8547 - val_loss: 0.3473
# Epoch 44/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7972 - loss: 0.4572 - val_accuracy: 0.8547 - val_loss: 0.3487
# Epoch 45/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8278 - loss: 0.4103 - val_accuracy: 0.8492 - val_loss: 0.3484
# Epoch 46/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8074 - loss: 0.4448 - val_accuracy: 0.8492 - val_loss: 0.3492
# Epoch 47/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8188 - loss: 0.4155 - val_accuracy: 0.8492 - val_loss: 0.3502
# Epoch 48/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8249 - loss: 0.4234 - val_accuracy: 0.8436 - val_loss: 0.3507
# Epoch 49/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8234 - loss: 0.4571 - val_accuracy: 0.8492 - val_loss: 0.3493
# Epoch 50/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8327 - loss: 0.4132 - val_accuracy: 0.8492 - val_loss: 0.3478
# Epoch 51/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8175 - loss: 0.4354 - val_accuracy: 0.8436 - val_loss: 0.3464
# Epoch 52/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8337 - loss: 0.3992 - val_accuracy: 0.8436 - val_loss: 0.3458
# Epoch 53/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8138 - loss: 0.4257 - val_accuracy: 0.8436 - val_loss: 0.3474
# Epoch 54/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8059 - loss: 0.4421 - val_accuracy: 0.8436 - val_loss: 0.3461
# Epoch 55/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8306 - loss: 0.4103 - val_accuracy: 0.8492 - val_loss: 0.3440
# Epoch 56/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8039 - loss: 0.4307 - val_accuracy: 0.8492 - val_loss: 0.3442
# Epoch 57/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8240 - loss: 0.4239 - val_accuracy: 0.8492 - val_loss: 0.3448
# Epoch 58/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8130 - loss: 0.4559 - val_accuracy: 0.8436 - val_loss: 0.3449
# Epoch 59/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8092 - loss: 0.4492 - val_accuracy: 0.8547 - val_loss: 0.3448
# Epoch 60/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8136 - loss: 0.4087 - val_accuracy: 0.8547 - val_loss: 0.3444
# Epoch 61/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8085 - loss: 0.4127 - val_accuracy: 0.8492 - val_loss: 0.3421
# Epoch 62/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8151 - loss: 0.4326 - val_accuracy: 0.8436 - val_loss: 0.3424
# Epoch 63/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8483 - loss: 0.4017 - val_accuracy: 0.8436 - val_loss: 0.3400
# Epoch 64/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8106 - loss: 0.4318 - val_accuracy: 0.8436 - val_loss: 0.3426
# Epoch 65/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8308 - loss: 0.4152 - val_accuracy: 0.8547 - val_loss: 0.3395
# Epoch 66/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8401 - loss: 0.3959 - val_accuracy: 0.8547 - val_loss: 0.3354
# Epoch 67/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8100 - loss: 0.4380 - val_accuracy: 0.8603 - val_loss: 0.3408
# Epoch 68/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8313 - loss: 0.4003 - val_accuracy: 0.8492 - val_loss: 0.3403
# Epoch 69/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8308 - loss: 0.4275 - val_accuracy: 0.8547 - val_loss: 0.3428
# Epoch 70/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8150 - loss: 0.4193 - val_accuracy: 0.8436 - val_loss: 0.3419
# Epoch 71/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8259 - loss: 0.4003 - val_accuracy: 0.8547 - val_loss: 0.3411
# Epoch 72/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8304 - loss: 0.3976 - val_accuracy: 0.8492 - val_loss: 0.3417
# Epoch 73/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8439 - loss: 0.4043 - val_accuracy: 0.8547 - val_loss: 0.3410
# Epoch 74/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7887 - loss: 0.4544 - val_accuracy: 0.8603 - val_loss: 0.3409
# Epoch 75/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8209 - loss: 0.4196 - val_accuracy: 0.8715 - val_loss: 0.3363
# Epoch 76/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7947 - loss: 0.4454 - val_accuracy: 0.8771 - val_loss: 0.3400
# Epoch 77/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8298 - loss: 0.4241 - val_accuracy: 0.8771 - val_loss: 0.3390
# Epoch 78/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8192 - loss: 0.4236 - val_accuracy: 0.8715 - val_loss: 0.3409
# Epoch 79/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8121 - loss: 0.4152 - val_accuracy: 0.8603 - val_loss: 0.3372
# Epoch 80/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7835 - loss: 0.5072 - val_accuracy: 0.8715 - val_loss: 0.3396
# Epoch 81/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8169 - loss: 0.4126 - val_accuracy: 0.8547 - val_loss: 0.3365
# Epoch 82/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8167 - loss: 0.4375 - val_accuracy: 0.8603 - val_loss: 0.3408
# Epoch 83/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8287 - loss: 0.4111 - val_accuracy: 0.8547 - val_loss: 0.3414
# Epoch 84/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8256 - loss: 0.4013 - val_accuracy: 0.8492 - val_loss: 0.3417
# Epoch 85/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8222 - loss: 0.4335 - val_accuracy: 0.8547 - val_loss: 0.3411
# Epoch 86/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8246 - loss: 0.4173 - val_accuracy: 0.8659 - val_loss: 0.3378
# Epoch 87/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8400 - loss: 0.4200 - val_accuracy: 0.8715 - val_loss: 0.3394
# Epoch 88/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8191 - loss: 0.4156 - val_accuracy: 0.8715 - val_loss: 0.3387
# Epoch 89/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8178 - loss: 0.4036 - val_accuracy: 0.8547 - val_loss: 0.3398
# Epoch 90/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8293 - loss: 0.4066 - val_accuracy: 0.8715 - val_loss: 0.3395
# Epoch 91/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8143 - loss: 0.4344 - val_accuracy: 0.8771 - val_loss: 0.3395
# Epoch 92/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8160 - loss: 0.4350 - val_accuracy: 0.8827 - val_loss: 0.3368
# Epoch 93/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8357 - loss: 0.4161 - val_accuracy: 0.8659 - val_loss: 0.3384
# Epoch 94/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8271 - loss: 0.4290 - val_accuracy: 0.8603 - val_loss: 0.3403
# Epoch 95/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8244 - loss: 0.4116 - val_accuracy: 0.8659 - val_loss: 0.3361
# Epoch 96/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8094 - loss: 0.4265 - val_accuracy: 0.8603 - val_loss: 0.3364
# Epoch 97/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8539 - loss: 0.3814 - val_accuracy: 0.8659 - val_loss: 0.3377
# Epoch 98/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8256 - loss: 0.4029 - val_accuracy: 0.8715 - val_loss: 0.3402
# Epoch 99/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8161 - loss: 0.4296 - val_accuracy: 0.8715 - val_loss: 0.3373
# Epoch 100/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8208 - loss: 0.4261 - val_accuracy: 0.8603 - val_loss: 0.3374
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step
# Predictions saved to predictions.csv

# %%
# Load test data again to get PassengerId
test_data = pd.read_csv("test.csv")

# Make predictions
predictions = (model.predict(X_test) > 0.5).astype(int)

# Save predictions with PassengerId
output = pd.DataFrame({"PassengerId": test_data["PassengerId"], "Prediction": predictions.flatten()})
output.to_csv("predictions.csv", index=False)

print("Predictions saved to predictions.csv")
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Predictions saved to predictions.csv
